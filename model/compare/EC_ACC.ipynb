# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset, TensorDataset
import matplotlib.pyplot as plt
import math, os, sys
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from typing import Tuple, List, Optional
import torch.optim as optim
import matplotlib.pyplot as plt
from typing import List, TypeVar, Any
from torch.autograd import grad
Tensor = TypeVar('torch.tensor')

# %%
EPS = 1e-8
class DummyUAVDataset(Dataset):
    def __init__(self, window_size=30, step_size=3, batch_size=8, mode='1-hover', phase='2_6'):
        self.window_size = window_size
        self.step_size = step_size

        base_data_path = os.path.join(os.getcwd(), '..', '..', 'data', 'Dpro', mode)
        columns = ['accelerometer_m_s2[0]','accelerometer_m_s2[1]', 'accelerometer_m_s2[2]']
        # columns = ['gyro_rad[0]', 'gyro_rad[1]', 'gyro_rad[2]', 'accelerometer_m_s2[0]', 'accelerometer_m_s2[1]', 'accelerometer_m_s2[2]', 'magnetometer_ga[0]', 'magnetometer_ga[1]', 'magnetometer_ga[2]']
        sim_data = pd.read_csv(base_data_path + f'/all_sycn_sim_data_mode{phase}.csv', usecols=columns).to_numpy()
        raw_data = pd.read_csv(base_data_path + f'/all_sycn_raw_data_mode{phase}.csv', usecols=columns).to_numpy()
        err_data = pd.read_csv(base_data_path + f'/all_sycn_err_data_mode{phase}.csv', usecols=columns).to_numpy()
        print(f'sim_data:{sim_data.shape} raw_data:{raw_data.shape} err_data:{err_data.shape}')

        self.dataset_x  = self.data_to_model(data=sim_data, sequence_length=window_size, step_size=step_size)
        self.dataset_y  = self.data_to_model(data=raw_data, sequence_length=window_size, step_size=step_size)
        self.dataset_e = self.data_to_model(data=err_data, sequence_length=window_size, step_size=step_size)
        print(f'dataset_x:{self.dataset_x.shape}')

        dataset = TensorDataset(self.dataset_x, self.dataset_y, self.dataset_e)
        self.dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, drop_last=True)
        
    def data_to_model(self, data, sequence_length=120, step_size=25):
        data = torch.tensor(data, dtype=float)
        sequences = []
        N = data.shape[0]
        
        for start_idx in range(0, N - sequence_length + 1, step_size):
            sequence = data[start_idx:start_idx + sequence_length]
            sequences.append(sequence)
        
        sequences = torch.stack(sequences)
        return sequences

# 1-hover 2-hover-accx-flag3-params03 4-hover-motor4-flag4-params085 5-hover-motor34-flag4-params08085 6-hover-motor234-flag4-params07508085 7-hover-motor3-flag3-params200
window_size, step_size, batch_size = 40, 5, 8
datasetuav = DummyUAVDataset(step_size=step_size, window_size=window_size, batch_size=batch_size, mode='7-hover-motor3-flag3-params200', phase='2_9')
# Out:
# sim_data:(3748, 3) raw_data:(3748, 3) err_data:(3748, 3)
# dataset_x:torch.Size([742, 40, 3])

# %%
########### MDN helper funcs ###########
def parse_mdn_outputs(z, K, d):
    """
    z: [B, T, out_dim] where out_dim = K*(1 + 2*d)
    returns:
      pi:   [B, T, K]
      mu:   [B, T, K, d]
      sigma:[B, T, K, d]   (std, positive)
    """
    B, T, out_dim = z.shape
    expected = K * (1 + 2 * d)
    assert out_dim == expected, f"out_dim mismatch: got {out_dim}, expected {expected}"
    # split
    z = z.view(B, T, -1)
    pi_logits = z[..., :K]                      # [B,T,K]
    mu_flat = z[..., K: K + K * d]             # [B,T,K*d]
    sigma_flat = z[..., K + K * d:]            # [B,T,K*d]
    mu = mu_flat.view(B, T, K, d)
    sigma = sigma_flat.view(B, T, K, d)
    # mixture weights with numerical stability
    pi = F.softmax(pi_logits, dim=-1)          # [B,T,K]
    # ensure positivity & numerical stability for sigma (model outputs log-sigma or raw)
    # we treat sigma_flat as unconstrained -> apply softplus or exp
    sigma = F.softplus(sigma) + 1e-6           # [B,T,K,d], softplus is stable
    return pi, mu, sigma

def mdn_nll(pi, mu, sigma, target, reduce_mean=True):
    """
    Negative log-likelihood of target under diagonal Gaussian mixture.
    pi: [B,T,K], mu: [B,T,K,d], sigma: [B,T,K,d], target: [B,T,d]
    returns: scalar loss (mean over batch & time) if reduce_mean True, else per-sample [B,T]
    """
    B, T, K = pi.shape
    d = target.shape[-1]
    tgt = target.unsqueeze(2)                   # [B,T,1,d]
    # compute exponent term: -0.5 * sum_d ((x - mu)^2 / sigma^2)
    var_term = ((tgt - mu) / (sigma + EPS)) ** 2   # [B,T,K,d]
    exp_term = -0.5 * torch.sum(var_term, dim=-1)  # [B,T,K]
    # log sigma term: - sum_d log(sigma)
    log_sigma = - torch.sum(torch.log(sigma + EPS), dim=-1)  # [B,T,K]
    const = -0.5 * d * math.log(2 * math.pi)                 # scalar
    log_prob_components = exp_term + log_sigma + const       # [B,T,K]
    log_pi = torch.log(pi + EPS)                             # [B,T,K]
    log_weighted = log_pi + log_prob_components              # [B,T,K]
    # log-sum-exp over mixture components => log p(x)
    log_prob = torch.logsumexp(log_weighted, dim=-1)         # [B,T]
    nll = -log_prob                                           # [B,T]
    if reduce_mean:
        return torch.mean(nll)
    else:
        return nll

def mdn_sample_step(pi, mu, sigma):
    """
    Sample one step from mixture.
    pi: [B, K], mu: [B, K, d], sigma: [B, K, d]
    returns sampled tensor [B, d]
    """
    B, K, d = mu.shape
    # sample component index for each batch
    comp = torch.multinomial(pi, num_samples=1).squeeze(-1)  # [B]
    idx = comp.view(B, 1, 1).expand(-1, 1, d)               # [B,1,d]
    mu_sel = torch.gather(mu, dim=1, index=idx).squeeze(1)  # [B,d]
    sigma_sel = torch.gather(sigma, dim=1, index=idx).squeeze(1)  # [B,d]
    eps = torch.randn_like(mu_sel)
    return mu_sel + sigma_sel * eps

def mdn_conditional_mean(pi, mu):
    """
    Compute conditional expectation E[x] = sum_k pi_k * mu_k
    pi: [B,T,K], mu: [B,T,K,d] -> returns [B,T,d]
    """
    # expand & sum
    # pi[..., None] * mu -> [B,T,K,d]
    mean = torch.sum(pi.unsqueeze(-1) * mu, dim=2)  # [B,T,d]
    return mean

def mdn_mixture_covariance(pi, mu, sigma):
    """
    Compute mixture covariance per time-step:
      Cov = sum_k pi_k (Sigma_k + mu_k mu_k^T) - mu_bar mu_bar^T
    pi: [B,T,K], mu: [B,T,K,d], sigma: [B,T,K,d] (sigma is std)
    returns: cov_diag [B,T,d] (diagonal covariance across dims)
    Note: we return diagonal cov for simplicity (matches diagonal Gaussian assumption).
    """
    # convert sigma (std) to var
    var = sigma ** 2  # [B,T,K,d]
    mu_bar = mdn_conditional_mean(pi, mu)  # [B,T,d]
    # compute E[xx^T] diagonal = sum_k pi_k (var_k + mu_k^2)
    exx_diag = torch.sum(pi.unsqueeze(-1) * (var + mu ** 2), dim=2)  # [B,T,d]
    cov_diag = exx_diag - mu_bar ** 2  # [B,T,d]
    return cov_diag  # diagonal of covariance

# ------------------------------
# Generator: LSTM + FC -> MDN params (supports conditional vector c_t)
# ------------------------------
class ErrGenerator(nn.Module):
    def __init__(self, out_dim=3, cond_dim=0, hidden_size=256, num_layers=2, fc_dim=128, num_mixtures=24, act='relu'):
        """
        out_dim: d (residual dimensionality)
        cond_dim: dimensionality of conditional vector c_t (can be 0)
        The input to LSTM at time t is [E_{t-1}, c_t] as specified.
        """
        super().__init__()
        self.d = out_dim
        self.cond_dim = cond_dim
        self.inp_dim = out_dim + cond_dim
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.num_mixtures = num_mixtures

        self.lstm = nn.LSTM(input_size=self.inp_dim, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, fc_dim)
        self.fc2 = nn.Linear(fc_dim, num_mixtures * (1 + 2 * self.d))  # K*(1 + 2*d)
        if act == 'sigmoid':
            self.act = torch.sigmoid
        elif act == 'tanh':
            self.act = torch.tanh
        elif act == 'relu':
            self.act = F.leaky_relu  
        else:
            self.act = lambda x: x  # identity

    def forward(self, prev_E, cond=None, hidden=None):
        """
        prev_E: tensor [B, T, d]  (these are inputs E_{t-1} aligned to outputs for next step)
        cond:   optional tensor [B, T, cond_dim] (if cond_dim>0)
        returns: pi [B,T,K], mu [B,T,K,d], sigma [B,T,K,d]
        """
        B, T, d_ = prev_E.shape
        assert d_ == self.d
        if self.cond_dim > 0:
            assert cond is not None
            assert cond.shape[0] == B and cond.shape[1] == T
            inp = torch.cat([prev_E, cond], dim=-1)  # [B,T,d+cond]
        else:
            inp = prev_E  # [B,T,d]
        out_seq, hidden = self.lstm(inp, hidden)     # out_seq: [B, T, hidden]
        z = self.act(self.fc1(out_seq))              # [B,T,fc_dim]
        z = self.fc2(z)                              # [B,T, out_dim]
        pi, mu, sigma = parse_mdn_outputs(z, self.num_mixtures, self.d)
        return pi, mu, sigma, hidden
    
    @torch.no_grad()
    def sample(self, seq_len, batch_size=1, device='cpu', start_input=None, cond_seq=None):
        """
        Autoregressive sampling:
        start_input: [B, d] or None -> used as E_0 input for first step
        cond_seq: optional [B, seq_len, cond_dim]
        returns samples [B, seq_len, d]
        """
        d = self.d
        if start_input is None:
            prev = torch.zeros(batch_size, 1, d, device=device)
        else:
            prev = start_input.view(batch_size, 1, d).to(device)
        # initialize hidden states
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_size, device=device)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_size, device=device)
        hidden = (h0, c0)
        samples = []
        for t in range(seq_len):
            cond_t = None
            if self.cond_dim > 0 and cond_seq is not None:
                cond_t = cond_seq[:, t:t+1, :]  # [B,1,cond_dim]
                inp = torch.cat([prev, cond_t], dim=-1)
            else:
                inp = prev
            out_seq, hidden = self.lstm(inp, hidden)   # out_seq [B,1,hidden]
            z = self.act(self.fc1(out_seq))            # [B,1,fc_dim]
            z = self.fc2(z)                            # [B,1,out_dim]
            pi, mu, sigma = parse_mdn_outputs(z.squeeze(1).unsqueeze(1), self.num_mixtures, d)
            # pi: [B,1,K] -> squeeze to [B,K]
            pi_step = pi.squeeze(1)    # [B,K]
            mu_step = mu.squeeze(1)    # [B,K,d]
            sigma_step = sigma.squeeze(1)  # [B,K,d]
            next_x = mdn_sample_step(pi_step, mu_step, sigma_step)  # [B,d]
            samples.append(next_x.unsqueeze(1))
            prev = next_x.unsqueeze(1)
        return torch.cat(samples, dim=1)  # [B, seq_len, d]

# ------------------------------
# Discriminators (WGAN critics)
# - Time-domain critic: LSTM -> FC -> scalar
# - Frequency-domain critic: compute rFFT along time, feed real+imag sequence to LSTM -> scalar
# ------------------------------
class TimeCritic(nn.Module):
    def __init__(self, input_dim=3, hidden_size=128, num_layers=1, dropout=0.1):
        super().__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True, bidirectional=False)

        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.fc2 = nn.Linear(hidden_size // 2, 1)  # 最终输出1个logit
        self.dropout = nn.Dropout(dropout)
        self.act = F.leaky_relu 

    def forward(self, x):
        """x: [B, T, d] -> returns scores [B]"""
        out_seq, _ = self.lstm(x)   # [B,T,hidden]
        last = out_seq[:, -1, :]    # 取最后一个时间步的特征
        z = self.act(self.fc1(last))
        z = self.dropout(z)
        score = self.fc2(z).squeeze(-1)  # [B]（logits）
        return score

class FreqCritic(nn.Module):
    def __init__(self, input_dim=3, hidden_size=128, num_layers=1, use_log_mag=True, dropout=0.1):
        super().__init__()
        self.use_log_mag = use_log_mag
        # 频率特征维度：use_log_mag时为d（log幅度），否则为2*d（实部+虚部）
        self.feat_dim = input_dim if use_log_mag else 2 * input_dim
        self.lstm = nn.LSTM(input_size=self.feat_dim, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        # 新增：稳定训练的组件
        self.ln = nn.LayerNorm(self.feat_dim)
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.fc2 = nn.Linear(hidden_size // 2, 1)
        self.dropout = nn.Dropout(dropout)
        self.act = F.leaky_relu

    def forward(self, x):
        """
        x: [B, T, d]（时域序列）
        正确逻辑：
        1. 时域转频域（rfft）-> [B, T_freq, d]（复数）
        2. 特征提取：use_log_mag=True → log幅度（[B,T_freq,d]）；否则 → 实部+虚部（[B,T_freq,2d]）
        3. 归一化+LSTM+FC → logits
        """
        # 1. 时域转频域（沿时间轴dim=1）
        Xf = torch.fft.rfft(x, dim=1)  # [B, T_freq, d]（复数）
        real = Xf.real
        imag = Xf.imag

        # 2. 提取频率特征（修复核心错误）
        if self.use_log_mag:
            # 计算幅度：sqrt(real² + imag²)，加EPS避免0
            mag = torch.sqrt(real ** 2 + imag ** 2 + EPS)
            feat = torch.log(mag + EPS)  # [B, T_freq, d]（log幅度，数值更稳定）
        else:
            feat = torch.cat([real, imag], dim=-1)  # [B, T_freq, 2d]（实部+虚部）

        # 3. 归一化（关键：稳定数值范围，避免梯度爆炸）
        feat = self.ln(feat)  # [B, T_freq, feat_dim]

        # 4. LSTM+FC特征提取
        out_seq, _ = self.lstm(feat)  # [B, T_freq, hidden]
        last = out_seq[:, -1, :]      # 取最后一个频率步的特征
        z = self.act(self.fc1(last))
        z = self.dropout(z)
        score = self.fc2(z).squeeze(-1)  # [B]（logits）

        return score

def wasserstein_loss(x, recon_x, std_weight=2):
    """
    计算 Wasserstein 损失（即 Earth Mover's Distance）
    :param x: 原始输入序列, 形状为 [batch_size, seq_len, input_dim]
    :param recon_x: 重建的序列, 形状为 [batch_size, seq_len, input_dim]
    :return: Wasserstein 损失
    """
    mean_x = torch.mean(x, dim=(0, 1))  # 计算原始数据的均值 [batch_size]
    std_x = torch.std(x, dim=(0, 1))    # 计算原始数据的标准差 [batch_size]

    mean_recon_x = torch.mean(recon_x, dim=(0, 1))  # 计算重建数据的均值 [batch_size]
    std_recon_x = torch.std(recon_x, dim=(0, 1))    # 计算重建数据的标准差 [batch_size]

    # 计算 Wasserstein 距离（均值差异 + 标准差差异）
    # Wasserstein 距离是均值差异和标准差差异的组合
    loss = torch.mean(torch.abs(mean_x - mean_recon_x) + std_weight * torch.abs(std_x - std_recon_x))

    return loss

# %%
# ------------------------------
# Critic (WGAN-GP) training for one epoch
# ------------------------------
def train_critics_epoch(time_critic, freq_critic, generator,
                        dataloader, opt_time, opt_freq,
                        device, lambda_recon=1.0, n_critic=5,
                        cond_dim=None):
    """
    Train both time & freq critics for one epoch over dataloader.
    For each batch, perform n_critic gradient steps for critics.
    """
    time_critic.train()
    freq_critic.train()
    total_time_loss = 0.0
    total_freq_loss = 0.0
    total_samples = 0
    criterion = nn.BCEWithLogitsLoss()

    for _, _, err in dataloader:
        real = err
        real = real.to(device, dtype=torch.float32)
        B, T, d = real.shape
        total_samples += B

        # Prepare generator inputs: teacher-forcing using real previous residuals
        # generator.forward expects prev_E: [B, T-1, d] (predict next-step)
        x_in = real[:, :-1, :]          # [B, T-1, d]
        cond_for_gen = None  # set if using conditional vectors aligned to timesteps

        # Run n_critic updates for critics using this batch
        for _ in range(n_critic):
            # Generate fake sequences (use conditional mean for stability)
            with torch.no_grad():
                pi, mu, sigma, _ = generator(x_in, cond=cond_for_gen)
                fake_mean = mdn_conditional_mean(pi, mu)   # [B, T-1, d]
                # Align fake sequence to same length T: prepend zeros (or shift)
                fake_seq = torch.cat([torch.zeros(B, 1, d, device=device), fake_mean], dim=1)  # [B,T,d]

            logits_real = time_critic(real)   # [B]
            logits_gen = time_critic(fake_seq.detach())
            # labels
            labels_real = torch.ones_like(logits_real, device=device)
            labels_gen = torch.zeros_like(logits_gen, device=device)
            loss_real = criterion(logits_real, labels_real)
            loss_gen = criterion(logits_gen, labels_gen)
            loss_time_total = 0.5 * (loss_real + loss_gen)
            loss_time_total.backward()
            opt_time.step()
            total_time_loss += loss_time_total.item() * B

            # Frequency critic update
            logits_real = freq_critic(real)   # [B]
            logits_gen = freq_critic(fake_seq.detach())
            # labels
            labels_real = torch.ones_like(logits_real, device=device)
            labels_gen = torch.zeros_like(logits_gen, device=device)
            loss_real = criterion(logits_real, labels_real)
            loss_gen = criterion(logits_gen, labels_gen)
            loss_freq_total = 0.5 * (loss_real + loss_gen)
            loss_freq_total.backward()
            opt_freq.step()
            total_freq_loss += loss_freq_total.item() * B

    avg_time_loss = total_time_loss / total_samples
    avg_freq_loss = total_freq_loss / total_samples
    return avg_time_loss, avg_freq_loss

# ------------------------------
# Generator training for one epoch
# ------------------------------
def train_generator_epoch(generator, time_critic, freq_critic, dataloader,
                          opt_G, device, lambda_recon = 1.0, lambda_mdn=1.0, lambda_wgan=1.0,
                          clip_grad=None, cond_dim=None):
    """
    Train generator over one epoch:
      Loss = lambda_mdn * MDN_NLL + lambda_wgan * WGAN_GeneratorLoss
    WGAN_GeneratorLoss = - E[ D_time(fake) ] - E[ D_freq(fake) ]
    """
    generator.train()
    total_loss = 0.0
    total_nll = 0.0
    total_wgan = 0.0
    total_recon = 0.0
    total_samples = 0

    for _, _, err in dataloader:
        real = err
        real = real.to(device, dtype=torch.float32)
        B, T, d = real.shape
        total_samples += B

        # inputs & targets for MDN (teacher forcing)
        x_in = real[:, :-1, :]       # [B, T-1, d]
        x_target = real[:, 1:, :]    # [B, T-1, d]
        cond_for_gen = None          # set if available

        # Forward generator
        pi, mu, sigma, _ = generator(x_in, cond=cond_for_gen)
        # MDN NLL computed on x_target
        nll = mdn_nll(pi, mu, sigma, x_target)  # scalar

        # Construct fake_seq for critic scoring (prepend zeros to align length)
        fake_mean = mdn_conditional_mean(pi, mu)  # [B, T-1, d]
        fake_seq = torch.cat([torch.zeros(B, 1, d, device=device), fake_mean], dim=1)  # [B, T, d]

        recon_loss = torch.mean(torch.square(real - fake_seq))  # MSE损失

        # WGAN generator loss: minimize -E[D(fake)] for both critics
        wgan_loss = wasserstein_loss(real, fake_seq)
        loss_G = lambda_mdn * nll + lambda_recon * recon_loss

        opt_G.zero_grad()
        loss_G.backward()
        if clip_grad is not None:
            torch.nn.utils.clip_grad_norm_(generator.parameters(), clip_grad)
        opt_G.step()

        total_loss += loss_G.item() * B
        total_nll += nll.item() * B
        total_wgan += wgan_loss.item() * B
        total_recon += recon_loss.item() * B

    avg_loss = total_loss / total_samples
    avg_nll = total_nll / total_samples
    avg_wgan = total_wgan / total_samples
    avg_recon = total_recon / total_samples
    return avg_loss, avg_nll, avg_wgan, avg_recon

# ------------------------------
# High-level training loop (替换 train_errCompensator)
# ------------------------------
def train_errCompensator(generator, time_critic, freq_critic, dataloader,
                         device='cpu',
                         dis_opt_time=None, dis_opt_freq=None, gen_opt=None,
                         batch_size=8,
                         dis_epochs_per_iter=200, gen_epochs_per_iter=100,
                         num_iters=10, n_critic=5, lambda_recon=1.0,
                         lambda_mdn=1.0, lambda_wgan=1.0, clip_grad=5.0):
    """
    Main training loop implementing alternating updates:
      For each iter:
        - train critics for dis_epochs_per_iter epochs (each epoch loops dataloader once)
        - train generator for gen_epochs_per_iter epochs
    Arguments:
      - generator: ErrGenerator instance
      - time_critic, freq_critic: critic networks (WGAN-GP style)
      - dataloader: DataLoader over residual sequences [N, T, d]
      - n_critic: number of critic steps per batch internal to train_critics_epoch
      - lambda_* : weights for loss terms
    """
    if dis_opt_time is None:
        dis_opt_time = optim.Adam(time_critic.parameters(), lr=1e-4, betas=(0.5, 0.9))
    if dis_opt_freq is None:
        dis_opt_freq = optim.Adam(freq_critic.parameters(), lr=1e-4, betas=(0.5, 0.9))
    if gen_opt is None:
        gen_opt = optim.RMSprop(generator.parameters(), lr=1e-4)

    # set device
    generator.to(device)
    time_critic.to(device)
    freq_critic.to(device)
    loss_records = {
        'total_loss': [], 
        'time_loss': [],
        'freq_loss': [],
        'nll_loss': [],    
        'wgan_loss': [],
        'recon_loss': [] 
    }

    for it in range(num_iters):
        print(f"=== Iter {it+1}/{num_iters} : train critics for {dis_epochs_per_iter} epochs ===")
        for e in range(dis_epochs_per_iter):
            avg_time_loss, avg_freq_loss = train_critics_epoch(
                time_critic, freq_critic, generator,
                dataloader, dis_opt_time, dis_opt_freq,
                device, lambda_recon=lambda_recon, n_critic=n_critic
            )
            if (e+1) % 50 == 0 or e == 0:
                print(f"  Critic epoch {e+1}/{dis_epochs_per_iter}, time_loss={avg_time_loss:.6f}, freq_loss={avg_freq_loss:.6f}")

        loss_records['time_loss'].append(avg_time_loss)
        loss_records['freq_loss'].append(avg_freq_loss)

        print(f"=== Iter {it+1}/{num_iters} : train generator for {gen_epochs_per_iter} epochs ===")
        for e in range(gen_epochs_per_iter):
            avg_loss, avg_nll, avg_wgan, avg_recon = train_generator_epoch(
                generator, time_critic, freq_critic, dataloader,
                gen_opt, device, lambda_recon = lambda_recon, lambda_mdn=lambda_mdn, lambda_wgan=lambda_wgan, 
                clip_grad=clip_grad
            )
            if (e+1) % 25 == 0 or e == 0:
                print(f"  G epoch {e+1}/{gen_epochs_per_iter}, total_loss={avg_loss:.6f}, nll={avg_nll:.6f}, wgan={avg_wgan:.6f} , recon={avg_recon:.6f}")

        loss_records['total_loss'].append(avg_loss)
        loss_records['nll_loss'].append(avg_nll)
        loss_records['wgan_loss'].append(avg_wgan) 
        loss_records['recon_loss'].append(avg_recon)  

    return generator, time_critic, freq_critic, loss_records

# %%
# --- instantiate models ---
dataloader = datasetuav.dataloader
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
gen = ErrGenerator(out_dim=3, cond_dim=0, hidden_size=256, num_layers=2, fc_dim=128, num_mixtures=24).to(device)
time_critic = TimeCritic(input_dim=3, hidden_size=128, num_layers=1).to(device)
freq_critic = FreqCritic(input_dim=3, hidden_size=128, num_layers=1).to(device)

# --- optimizers ---
dis_opt_time = torch.optim.Adam(time_critic.parameters(), lr=1e-4, betas=(0.5,0.9))
dis_opt_freq = torch.optim.Adam(freq_critic.parameters(), lr=1e-4, betas=(0.5,0.9))
gen_opt = torch.optim.RMSprop(gen.parameters(), lr=1e-3)  # paper used RMSProp for G

# %%
# --- run training (uses the train_errCompensator implementation provided earlier) ---
gen, time_critic, freq_critic, loss_records = train_errCompensator(
    generator=gen,
    time_critic=time_critic,
    freq_critic=freq_critic,
    dataloader=dataloader,
    device=device,
    dis_opt_time=dis_opt_time,
    dis_opt_freq=dis_opt_freq,
    gen_opt=gen_opt,
    batch_size=8,
    dis_epochs_per_iter=1,    # you set small values for quick runs
    gen_epochs_per_iter=1,
    num_iters=100,
    n_critic=1,
    lambda_recon=1.0,
    lambda_mdn=1.0,
    lambda_wgan=1.0,
    clip_grad=None
)
# Out:
# === Iter 1/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.681768, freq_loss=0.655694
# === Iter 1/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=5.176062, nll=4.120005, wgan=1.741747 , recon=1.056057
# === Iter 2/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.610243, freq_loss=0.725724
# === Iter 2/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.580115, nll=3.746543, wgan=1.259593 , recon=0.833573
# === Iter 3/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.582720, freq_loss=0.679790
# === Iter 3/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.488548, nll=3.680980, wgan=1.177056 , recon=0.807568
# === Iter 4/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694402, freq_loss=0.662853
# === Iter 4/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.415303, nll=3.626583, wgan=1.114145 , recon=0.788720
# === Iter 5/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.668147, freq_loss=0.375814
# === Iter 5/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.376491, nll=3.595968, wgan=1.087725 , recon=0.780523
# === Iter 6/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.691946, freq_loss=0.206772
# === Iter 6/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.338092, nll=3.563351, wgan=1.070828 , recon=0.774741
# === Iter 7/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=1.094867, freq_loss=0.204170
# === Iter 7/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.296924, nll=3.530078, wgan=1.055975 , recon=0.766846
# === Iter 8/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.684442, freq_loss=0.096078
# === Iter 8/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.245991, nll=3.488365, wgan=1.032902 , recon=0.757626
# === Iter 9/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.600382, freq_loss=0.081719
# === Iter 9/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.191928, nll=3.444151, wgan=1.010179 , recon=0.747777
# === Iter 10/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.690486, freq_loss=0.103697
# === Iter 10/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.135881, nll=3.400039, wgan=0.993093 , recon=0.735842
# === Iter 11/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.685007, freq_loss=0.104262
# === Iter 11/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=4.041390, nll=3.320459, wgan=0.962306 , recon=0.720931
# === Iter 12/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.691257, freq_loss=0.234495
# === Iter 12/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.953838, nll=3.245569, wgan=0.939200 , recon=0.708269
# === Iter 13/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692318, freq_loss=0.353503
# === Iter 13/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.859553, nll=3.164155, wgan=0.919135 , recon=0.695397
# === Iter 14/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692596, freq_loss=0.413234
# === Iter 14/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.766429, nll=3.086099, wgan=0.899419 , recon=0.680329
# === Iter 15/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693914, freq_loss=0.333169
# === Iter 15/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.659177, nll=2.993711, wgan=0.877614 , recon=0.665466
# === Iter 16/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.695313, freq_loss=0.333874
# === Iter 16/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.564395, nll=2.911506, wgan=0.865086 , recon=0.652888
# === Iter 17/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.695819, freq_loss=0.335786
# === Iter 17/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.439447, nll=2.804704, wgan=0.837922 , recon=0.634743
# === Iter 18/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694375, freq_loss=0.338919
# === Iter 18/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.321705, nll=2.698827, wgan=0.821093 , recon=0.622877
# === Iter 19/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693496, freq_loss=0.269237
# === Iter 19/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.203897, nll=2.597253, wgan=0.807532 , recon=0.606644
# === Iter 20/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693258, freq_loss=0.327502
# === Iter 20/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=3.089689, nll=2.493914, wgan=0.795748 , recon=0.595775
# === Iter 21/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693109, freq_loss=0.289244
# === Iter 21/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.957176, nll=2.375241, wgan=0.779361 , recon=0.581935
# === Iter 22/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694253, freq_loss=0.332548
# === Iter 22/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.846833, nll=2.276148, wgan=0.767488 , recon=0.570685
# === Iter 23/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694205, freq_loss=0.304958
# === Iter 23/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.737302, nll=2.177669, wgan=0.756254 , recon=0.559633
# === Iter 24/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694748, freq_loss=0.374161
# === Iter 24/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.600669, nll=2.055902, wgan=0.751374 , recon=0.544767
# === Iter 25/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694857, freq_loss=0.360122
# === Iter 25/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.527536, nll=1.993985, wgan=0.734023 , recon=0.533551
# === Iter 26/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694386, freq_loss=0.304096
# === Iter 26/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.379023, nll=1.856448, wgan=0.719349 , recon=0.522575
# === Iter 27/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693380, freq_loss=0.333241
# === Iter 27/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.295643, nll=1.786255, wgan=0.706248 , recon=0.509389
# === Iter 28/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693227, freq_loss=0.330990
# === Iter 28/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.169751, nll=1.669225, wgan=0.706153 , recon=0.500526
# === Iter 29/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692961, freq_loss=0.396679
# === Iter 29/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=2.075394, nll=1.585627, wgan=0.688605 , recon=0.489766
# === Iter 30/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693750, freq_loss=0.345032
# === Iter 30/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.962345, nll=1.482810, wgan=0.688772 , recon=0.479535
# === Iter 31/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692505, freq_loss=0.353950
# === Iter 31/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.869501, nll=1.398826, wgan=0.677356 , recon=0.470675
# === Iter 32/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694035, freq_loss=0.407920
# === Iter 32/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.735947, nll=1.276666, wgan=0.666206 , recon=0.459281
# === Iter 33/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693898, freq_loss=0.400076
# === Iter 33/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.659935, nll=1.209094, wgan=0.655196 , recon=0.450841
# === Iter 34/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693965, freq_loss=0.373367
# === Iter 34/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.590244, nll=1.149191, wgan=0.642838 , recon=0.441053
# === Iter 35/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692960, freq_loss=0.403298
# === Iter 35/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.503471, nll=1.070295, wgan=0.640120 , recon=0.433177
# === Iter 36/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692872, freq_loss=0.414316
# === Iter 36/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.378932, nll=0.953910, wgan=0.629742 , recon=0.425022
# === Iter 37/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694073, freq_loss=0.387531
# === Iter 37/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.322697, nll=0.907590, wgan=0.618763 , recon=0.415106
# === Iter 38/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692223, freq_loss=0.428045
# === Iter 38/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.224869, nll=0.818298, wgan=0.616584 , recon=0.406570
# === Iter 39/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693309, freq_loss=0.421092
# === Iter 39/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.148092, nll=0.747160, wgan=0.607016 , recon=0.400932
# === Iter 40/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692789, freq_loss=0.470399
# === Iter 40/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=1.068540, nll=0.677388, wgan=0.600183 , recon=0.391151
# === Iter 41/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692155, freq_loss=0.436822
# === Iter 41/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.983442, nll=0.598188, wgan=0.597553 , recon=0.385254
# === Iter 42/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693987, freq_loss=0.448155
# === Iter 42/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.848802, nll=0.473337, wgan=0.585032 , recon=0.375465
# === Iter 43/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693213, freq_loss=0.461604
# === Iter 43/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.832271, nll=0.462371, wgan=0.578574 , recon=0.369900
# === Iter 44/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.693320, freq_loss=0.509280
# === Iter 44/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.756885, nll=0.396958, wgan=0.570277 , recon=0.359926
# === Iter 45/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.691436, freq_loss=0.480667
# === Iter 45/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.636642, nll=0.283419, wgan=0.558818 , recon=0.353223
# === Iter 46/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.691180, freq_loss=0.489040
# === Iter 46/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.618557, nll=0.271542, wgan=0.562200 , recon=0.347016
# === Iter 47/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692251, freq_loss=0.496616
# === Iter 47/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.509504, nll=0.172752, wgan=0.547626 , recon=0.336752
# === Iter 48/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.692141, freq_loss=0.539153
# === Iter 48/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.489169, nll=0.156378, wgan=0.538001 , recon=0.332791
# === Iter 49/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.690780, freq_loss=0.523443
# === Iter 49/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.368407, nll=0.043344, wgan=0.534102 , recon=0.325063
# === Iter 50/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.694062, freq_loss=0.560896
# === Iter 50/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.303818, nll=-0.013817, wgan=0.528845 , recon=0.317635
# === Iter 51/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.695192, freq_loss=0.574892
# === Iter 51/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.239224, nll=-0.070389, wgan=0.512806 , recon=0.309613
# === Iter 52/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.688859, freq_loss=0.573587
# === Iter 52/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.169731, nll=-0.134530, wgan=0.506808 , recon=0.304261
# === Iter 53/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.689363, freq_loss=0.551223
# === Iter 53/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.098871, nll=-0.198178, wgan=0.501391 , recon=0.297049
# === Iter 54/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.690184, freq_loss=0.579246
# === Iter 54/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=0.022920, nll=-0.270064, wgan=0.496610 , recon=0.292984
# === Iter 55/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.689905, freq_loss=0.591994
# === Iter 55/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.037966, nll=-0.322144, wgan=0.488487 , recon=0.284178
# === Iter 56/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.687123, freq_loss=0.572580
# === Iter 56/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.092755, nll=-0.371776, wgan=0.480280 , recon=0.279021
# === Iter 57/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.686898, freq_loss=0.564810
# === Iter 57/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.148467, nll=-0.421110, wgan=0.471617 , recon=0.272643
# === Iter 58/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.687856, freq_loss=0.608096
# === Iter 58/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.226600, nll=-0.494639, wgan=0.465895 , recon=0.268040
# === Iter 59/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.686291, freq_loss=0.586535
# === Iter 59/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.257010, nll=-0.518712, wgan=0.453899 , recon=0.261702
# === Iter 60/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.683417, freq_loss=0.586427
# === Iter 60/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.374801, nll=-0.629529, wgan=0.448338 , recon=0.254728
# === Iter 61/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.685092, freq_loss=0.596306
# === Iter 61/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.422312, nll=-0.670734, wgan=0.443275 , recon=0.248422
# === Iter 62/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.685923, freq_loss=0.624524
# === Iter 62/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.431546, nll=-0.677209, wgan=0.443281 , recon=0.245663
# === Iter 63/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.679957, freq_loss=0.610853
# === Iter 63/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.491653, nll=-0.732500, wgan=0.432400 , recon=0.240847
# === Iter 64/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.687905, freq_loss=0.613266
# === Iter 64/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.590232, nll=-0.825694, wgan=0.423530 , recon=0.235462
# === Iter 65/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.680380, freq_loss=0.611068
# === Iter 65/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.643858, nll=-0.873061, wgan=0.416423 , recon=0.229203
# === Iter 66/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.680087, freq_loss=0.631746
# === Iter 66/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.656282, nll=-0.882961, wgan=0.412951 , recon=0.226680
# === Iter 67/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.673233, freq_loss=0.619887
# === Iter 67/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.731307, nll=-0.951549, wgan=0.402974 , recon=0.220242
# === Iter 68/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.675492, freq_loss=0.614375
# === Iter 68/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.809832, nll=-1.025559, wgan=0.401190 , recon=0.215727
# === Iter 69/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.667662, freq_loss=0.625056
# === Iter 69/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.819235, nll=-1.031948, wgan=0.386116 , recon=0.212713
# === Iter 70/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.665999, freq_loss=0.613756
# === Iter 70/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.900406, nll=-1.107819, wgan=0.387900 , recon=0.207413
# === Iter 71/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.666717, freq_loss=0.629385
# === Iter 71/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-0.912618, nll=-1.115638, wgan=0.376903 , recon=0.203020
# === Iter 72/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.661746, freq_loss=0.632301
# === Iter 72/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.013339, nll=-1.212762, wgan=0.372908 , recon=0.199423
# === Iter 73/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.657377, freq_loss=0.640740
# === Iter 73/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.023614, nll=-1.219580, wgan=0.367585 , recon=0.195966
# === Iter 74/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.648153, freq_loss=0.626732
# === Iter 74/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.087472, nll=-1.279351, wgan=0.364360 , recon=0.191878
# === Iter 75/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.645420, freq_loss=0.640429
# === Iter 75/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.121204, nll=-1.308152, wgan=0.351977 , recon=0.186949
# === Iter 76/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.636277, freq_loss=0.659199
# === Iter 76/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.201062, nll=-1.383723, wgan=0.346920 , recon=0.182661
# === Iter 77/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.631646, freq_loss=0.635326
# === Iter 77/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.240365, nll=-1.420968, wgan=0.344678 , recon=0.180603
# === Iter 78/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.632879, freq_loss=0.640176
# === Iter 78/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.285114, nll=-1.462371, wgan=0.334605 , recon=0.177257
# === Iter 79/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.610817, freq_loss=0.650807
# === Iter 79/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.271161, nll=-1.446189, wgan=0.330023 , recon=0.175028
# === Iter 80/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.621174, freq_loss=0.659587
# === Iter 80/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.380524, nll=-1.551718, wgan=0.329696 , recon=0.171194
# === Iter 81/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.608991, freq_loss=0.637445
# === Iter 81/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.418179, nll=-1.587005, wgan=0.321239 , recon=0.168827
# === Iter 82/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.600419, freq_loss=0.664154
# === Iter 82/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.448313, nll=-1.614132, wgan=0.315478 , recon=0.165819
# === Iter 83/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.599034, freq_loss=0.660508
# === Iter 83/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.435788, nll=-1.600155, wgan=0.312741 , recon=0.164367
# === Iter 84/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.580687, freq_loss=0.666372
# === Iter 84/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.546499, nll=-1.706091, wgan=0.301506 , recon=0.159592
# === Iter 85/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.564657, freq_loss=0.658287
# === Iter 85/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.575586, nll=-1.733436, wgan=0.299505 , recon=0.157850
# === Iter 86/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.571520, freq_loss=0.657540
# === Iter 86/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.596141, nll=-1.751446, wgan=0.298609 , recon=0.155305
# === Iter 87/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.550127, freq_loss=0.663832
# === Iter 87/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.627960, nll=-1.781855, wgan=0.289366 , recon=0.153895
# === Iter 88/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.538573, freq_loss=0.656156
# === Iter 88/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.667758, nll=-1.818642, wgan=0.288550 , recon=0.150884
# === Iter 89/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.535496, freq_loss=0.666413
# === Iter 89/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.690814, nll=-1.839530, wgan=0.283600 , recon=0.148716
# === Iter 90/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.528379, freq_loss=0.654321
# === Iter 90/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.765772, nll=-1.912411, wgan=0.274419 , recon=0.146639
# === Iter 91/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.511735, freq_loss=0.656527
# === Iter 91/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.745382, nll=-1.891588, wgan=0.274944 , recon=0.146206
# === Iter 92/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.505963, freq_loss=0.652713
# === Iter 92/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.785230, nll=-1.927410, wgan=0.267120 , recon=0.142180
# === Iter 93/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.493721, freq_loss=0.670950
# === Iter 93/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.829949, nll=-1.971198, wgan=0.265195 , recon=0.141249
# === Iter 94/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.483026, freq_loss=0.672669
# === Iter 94/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.820884, nll=-1.960690, wgan=0.264912 , recon=0.139806
# === Iter 95/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.462014, freq_loss=0.670079
# === Iter 95/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.903068, nll=-2.041041, wgan=0.261319 , recon=0.137973
# === Iter 96/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.474500, freq_loss=0.659149
# === Iter 96/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.919394, nll=-2.055626, wgan=0.253430 , recon=0.136232
# === Iter 97/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.492999, freq_loss=0.658993
# === Iter 97/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.941152, nll=-2.075908, wgan=0.252183 , recon=0.134755
# === Iter 98/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.480152, freq_loss=0.657927
# === Iter 98/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-1.982408, nll=-2.115909, wgan=0.247422 , recon=0.133501
# === Iter 99/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.475296, freq_loss=0.662745
# === Iter 99/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-2.015921, nll=-2.147573, wgan=0.243908 , recon=0.131652
# === Iter 100/100 : train critics for 1 epochs ===
#   Critic epoch 1/1, time_loss=0.493845, freq_loss=0.653442
# === Iter 100/100 : train generator for 1 epochs ===
#   G epoch 1/1, total_loss=-2.010754, nll=-2.141680, wgan=0.242437 , recon=0.130925

# %%
plt.figure(figsize=(16, 6))
plt.subplot(1, 3, 1)
plt.plot(loss_records['recon_loss'], label="recon_loss")
plt.legend()
plt.subplot(1, 3, 2)
plt.plot(loss_records['nll_loss'], label="nll_loss")
plt.legend()
plt.subplot(1, 3, 3)
plt.plot(loss_records['wgan_loss'], label="wgan_loss")
plt.legend()
plt.tight_layout()
plt.show()

# %%
from scipy.stats import wasserstein_distance
from sklearn.metrics import r2_score

def calculate_wasserstein_distance(pred, true):
    """计算Wasserstein距离（Earth Mover's Distance）"""
    wasserstein_dist = 0
    D = pred.shape[1]  # 特征数
    
    for d in range(D):
        pred_data = pred[:, d].cpu().numpy()
        true_data = true[:, d].cpu().numpy()
        # 计算单特征的Wasserstein距离
        wasserstein_dist += wasserstein_distance(pred_data, true_data)
    
    return wasserstein_dist / D  # 返回所有特征的平均距离

def evaluate(model, test_loader, device, look_id=4):
    model.eval()
    metrics = {
        'mse': 0.0,
        'mae': 0.0,
        'rmse': 0.0,
        'r2': 0.0,
        'wasserstein': 0.0,
    }
    count = 0
    total_samples = 0
    predictions = []
    true_data = []
    origin_sim = []
    with torch.no_grad():
        for sim, raw, err in test_loader:
            B, N, M = sim.shape 
            gen_err = model.sample(seq_len=N, batch_size=B, device=device)
            # print(f'gen shape:{gen.shape} yb shape:{yb.shape}')
            total_samples += B

            compensated_sim = sim.to(device) - gen_err  # [B, N, 3]
            raw = raw.to(device) 

            predictions.append(sim.to(device) - gen_err)
            true_data.append(raw.to(device))
            origin_sim.append(sim.to(device))

            mse = F.mse_loss(compensated_sim, raw, reduction='mean')
            mae = F.l1_loss(compensated_sim, raw, reduction='mean')
            rmse = torch.sqrt(mse)
            r2 = r2_score(
                raw.cpu().numpy().reshape(-1, M),
                compensated_sim.cpu().numpy().reshape(-1, M)
            )

            metrics['mse'] += mse.item() * B
            metrics['mae'] += mae.item() * B
            metrics['rmse'] += rmse.item() * B
            metrics['r2'] += r2 * B
            metrics['wasserstein'] += calculate_wasserstein_distance(raw.reshape(-1, M), compensated_sim.reshape(-1, M))

            recon_err_denorm = gen_err.detach().cpu().numpy()
            raw_denorm = raw.detach().cpu().numpy()
            sim_denorm = sim.detach().cpu().numpy()
            sim_recon_denorm = sim_denorm - recon_err_denorm

            count += 1

            if count == look_id:  
                real_np = raw_denorm[0] 
                sim_np = sim_denorm[0]
                recon_np = sim_recon_denorm[0]

                plt.figure(figsize=(16, 6))
                for i in range(3):
                    plt.subplot(1, 3, i+1)
                    plt.plot(recon_np[:, i], label="Recon")
                    plt.plot(sim_np[:, i], label="Sim")
                    plt.plot(real_np[:, i], label="Real", linestyle='--')
                    plt.title(f'Channel {i+1}')
                    plt.legend()
                plt.tight_layout()
                plt.show()

    compensated_dataset_x = torch.cat(predictions, dim=0)
    raw_dataset_y = torch.cat(true_data, dim=0)
    origin_dataset_x = torch.cat(origin_sim, dim=0)

    for key in metrics:
        metrics[key] /= count

    print(f"✅ 测试集评估指标:")
    print(f"    MSE: {metrics['mse']:.6f}")
    print(f"    MAE: {metrics['mae']:.6f}")
    print(f"    RMSE: {metrics['rmse']:.6f}")
    print(f"    R² Score: {metrics['r2']:.6f}")
    print(f"    Wasserstein Distance: {metrics['wasserstein']:.6f}")

    return compensated_dataset_x, raw_dataset_y, origin_dataset_x

dataloader = datasetuav.dataloader
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]
plt.rcParams["axes.unicode_minus"] = False

compensated_dataset_x, raw_dataset_y, origin_dataset_x = evaluate(gen, dataloader, device = 'cuda' if torch.cuda.is_available() else 'cpu', look_id=50)
# Out:
# ✅ 测试集评估指标:
#     MSE: 15.686655
#     MAE: 8.656757
#     RMSE: 11.172676
#     R² Score: -14.933232
#     Wasserstein Distance: 0.411610

# %%
# 1-hover                               -> center
# 2-hover-accx-flag3-params03           -> center
# 4-hover-motor4-flag4-params085        -> center
# 5-hover-motor34-flag4-params08085     -> center
# 6-hover-motor234-flag4-params07508085 -> center

def reverse_data_to_model(compensated_dataset_x, sequence_length, step_size, strategy='center'): # last first center mean
    if isinstance(compensated_dataset_x, torch.Tensor):
        seq = compensated_dataset_x.detach().cpu().numpy()
    else:
        seq = np.asarray(compensated_dataset_x)
    
    S, L, F_in = seq.shape
    assert L == sequence_length, f"sequence_length ({sequence_length}) != sequences L ({L})"
    N_rec = (S - 1) * step_size + sequence_length

    if strategy not in ('center', 'last', 'first', 'mean'):
        raise ValueError("strategy must be 'center', 'last' , 'mean' or 'first'")

    # 快速处理单序列（无重叠）情况
    if S == 1:
        return seq[0].astype(np.float32)

    # 预分配
    recovered = np.zeros((N_rec, F_in), dtype=seq.dtype)
    # 为策略 'center' 我们需要记录候选值与其“距离中心”的度量
    if strategy == 'center':
        # 初始化距离为 +inf，越小越优先
        best_dist = np.full((N_rec,), np.inf, dtype=np.float64)
        center = (sequence_length - 1) / 2.0  # 窗口中心（可为非整数）
        # 遍历每个序列窗口，检查覆盖区间
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            # t 的本地位置 local_pos = t - start, 范围 0..L-1
            # 对区间内每个 t，计算 distance = abs(local_pos - center)
            # 向量化处理：
            local_positions = np.arange(sequence_length)  # 0..L-1
            dists = np.abs(local_positions - center)     # length L
            # 对每个时间点 t = start + k:
            for k in range(sequence_length):
                t = start + k
                dist = dists[k]
                if dist < best_dist[t]:
                    best_dist[t] = dist
                    recovered[t] = seq[i, k]
                # 若相等（几乎不会出现），保留已记录（可改为后写或先写）
        return recovered.astype(np.float32)

    elif strategy == 'last':
        # 后写覆盖：按序列顺序写入，每次直接覆盖（等同于最后出现的序列胜出）
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            recovered[start:end] = seq[i]
        return recovered.astype(np.float32)
    
    elif strategy == 'mean':
        counts = np.zeros((N_rec, F_in), dtype=np.float32)  
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            recovered[start:end] += seq[i]
            counts[start:end] += 1
        mask_overlap = counts > 1 
        recovered[mask_overlap] = recovered[mask_overlap] / counts[mask_overlap]

        return recovered.astype(np.float32)
    
    else:  # strategy == 'first'
        # 先写保留：第一次写进的值不被后续覆盖
        filled = np.zeros((N_rec,), dtype=bool)
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            for k in range(sequence_length):
                t = start + k
                if not filled[t]:
                    recovered[t] = seq[i, k]
                    filled[t] = True
        return recovered.astype(np.float32)

recovered_sim_data = reverse_data_to_model(
    compensated_dataset_x=compensated_dataset_x,
    sequence_length=window_size,
    step_size=step_size
) 

recovered_raw_data = reverse_data_to_model(
    compensated_dataset_x=raw_dataset_y,
    sequence_length=window_size,
    step_size=step_size
)

recovered_raw_sim_data = reverse_data_to_model(
    compensated_dataset_x=origin_dataset_x,
    sequence_length=window_size,
    step_size=step_size
)

print(f'recovered_sim_data shape: {recovered_sim_data.shape} recovered_raw_data shape: {recovered_raw_data.shape}')
plt.figure(figsize=(16, 6))
length_ = 3748
for i in range(recovered_sim_data.shape[1]):
    plt.subplot(1, 3, i+1)
    plt.plot(recovered_raw_data[:length_, i], label="Raw", linestyle='--')
    plt.plot(recovered_sim_data[:length_, i], label="Recon")
    plt.plot(recovered_raw_sim_data[:length_, i], label="Sim", linestyle='--')
    plt.title(f'Channel {i+1}')
    plt.legend()
plt.suptitle("GCN预测 vs 真实输出（样本）")
plt.tight_layout()
plt.show()
# Out:
# recovered_sim_data shape: (3715, 3) recovered_raw_data shape: (3715, 3)

# %%
def generate_compensated(dataset_instance, model, device):
    compensated_sequences_x_acc_list = []
    compensated_sequences_e_acc_list = []
    raw_sequences_y_acc_list = []
    raw_sequences_x_acc_list = []

    model.eval()
    with torch.no_grad():
        for xb, yb, eb in dataset_instance.dataloader:
            xb_acc = xb.to(device)
            yb_acc = yb.to(device)
            eb_acc = eb.to(device)
            B, W, _ = eb.shape 
            
            F_in_acc = eb_acc.shape[-1] 
            gen_std_acc = model.sample(seq_len=W, batch_size=B, device=device)
            pred_err_acc = gen_std_acc.view(gen_std_acc.size(0), -1, F_in_acc).to(device)
            target_recon_acc = xb_acc - pred_err_acc  
            target_err_acc = target_recon_acc - yb_acc 

            compensated_sequences_x_acc_list.append(target_recon_acc)
            compensated_sequences_e_acc_list.append(target_err_acc)
            raw_sequences_y_acc_list.append(yb_acc)
            raw_sequences_x_acc_list.append(xb_acc)


    compensated_dataset_x_acc = torch.cat(compensated_sequences_x_acc_list, dim=0) 
    raw_dataset_y_acc = torch.cat(raw_sequences_y_acc_list, dim=0)
    raw_dataset_x_acc = torch.cat(raw_sequences_x_acc_list, dim=0)

    return compensated_dataset_x_acc, raw_dataset_y_acc, raw_dataset_x_acc

base_path = os.path.join(os.getcwd(), '..', '..')
sys.path.append(base_path)
from model.compare.utils.EC import *
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
folder_name = 'EC_TFCritic_ACC_HOVER_M1F3'
model_name = 'EC_TFCritic_ACC_HOVER_M1F3.pth'
model_path = os.path.join(os.getcwd(), '..', 'compare', folder_name, model_name)
EC_model_Acc = torch.load(model_path)
EC_model_Acc.to(device)

recovered_sim_acc_data, recovered_raw_acc_data, recovered_raw_sim_acc_data = generate_compensated(
    dataset_instance=datasetuav,
    model=EC_model_Acc,
    device=device
)

# %%
def reverse_data_to_model(compensated_dataset_x, sequence_length, step_size, strategy='center'): # last first center mean
    if isinstance(compensated_dataset_x, torch.Tensor):
        seq = compensated_dataset_x.detach().cpu().numpy()
    else:
        seq = np.asarray(compensated_dataset_x)
    
    S, L, F_in = seq.shape
    assert L == sequence_length, f"sequence_length ({sequence_length}) != sequences L ({L})"
    N_rec = (S - 1) * step_size + sequence_length

    if strategy not in ('center', 'last', 'first', 'mean'):
        raise ValueError("strategy must be 'center', 'last' , 'mean' or 'first'")

    # 快速处理单序列（无重叠）情况
    if S == 1:
        return seq[0].astype(np.float32)

    # 预分配
    recovered = np.zeros((N_rec, F_in), dtype=seq.dtype)
    # 为策略 'center' 我们需要记录候选值与其“距离中心”的度量
    if strategy == 'center':
        # 初始化距离为 +inf，越小越优先
        best_dist = np.full((N_rec,), np.inf, dtype=np.float64)
        center = (sequence_length - 1) / 2.0  # 窗口中心（可为非整数）
        # 遍历每个序列窗口，检查覆盖区间
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            # t 的本地位置 local_pos = t - start, 范围 0..L-1
            # 对区间内每个 t，计算 distance = abs(local_pos - center)
            # 向量化处理：
            local_positions = np.arange(sequence_length)  # 0..L-1
            dists = np.abs(local_positions - center)     # length L
            # 对每个时间点 t = start + k:
            for k in range(sequence_length):
                t = start + k
                dist = dists[k]
                if dist < best_dist[t]:
                    best_dist[t] = dist
                    recovered[t] = seq[i, k]
                # 若相等（几乎不会出现），保留已记录（可改为后写或先写）
        return recovered.astype(np.float32)

    elif strategy == 'last':
        # 后写覆盖：按序列顺序写入，每次直接覆盖（等同于最后出现的序列胜出）
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            recovered[start:end] = seq[i]
        return recovered.astype(np.float32)
    
    elif strategy == 'mean':
        counts = np.zeros((N_rec, F_in), dtype=np.float32)  
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            recovered[start:end] += seq[i]
            counts[start:end] += 1
        mask_overlap = counts > 1 
        recovered[mask_overlap] = recovered[mask_overlap] / counts[mask_overlap]

        return recovered.astype(np.float32)
    
    else:  # strategy == 'first'
        # 先写保留：第一次写进的值不被后续覆盖
        filled = np.zeros((N_rec,), dtype=bool)
        for i in range(S):
            start = i * step_size
            end = start + sequence_length
            for k in range(sequence_length):
                t = start + k
                if not filled[t]:
                    recovered[t] = seq[i, k]
                    filled[t] = True
        return recovered.astype(np.float32)

recovered_sim_data = reverse_data_to_model(
    compensated_dataset_x=recovered_sim_acc_data,
    sequence_length=datasetuav.window_size,
    step_size=datasetuav.step_size
) 

recovered_raw_sim_data = reverse_data_to_model(
    compensated_dataset_x=recovered_raw_sim_acc_data,
    sequence_length=datasetuav.window_size,
    step_size=datasetuav.step_size
) 

recovered_raw_data = reverse_data_to_model(
    compensated_dataset_x=recovered_raw_acc_data,
    sequence_length=datasetuav.window_size,
    step_size=datasetuav.step_size
)

print(f'recovered_sim_acc_data:{recovered_sim_acc_data.shape} recovered_raw_acc_data:{recovered_raw_acc_data.shape}')

plt.figure(figsize=(16, 6))
length_ = 10000
for i in range(recovered_sim_data.shape[1]):
    plt.subplot(1, 3, i+1)
    plt.plot(recovered_raw_data[:length_, i], label="Raw", linestyle='--')
    plt.plot(recovered_sim_data[:length_, i], label="Recon")
    plt.plot(recovered_raw_sim_data[:length_, i], label="Sim", linestyle='--')
    plt.title(f'Channel {i+1}')
    plt.legend()
plt.tight_layout()
plt.show()
# Out:
# recovered_sim_acc_data:torch.Size([736, 40, 3]) recovered_raw_acc_data:torch.Size([736, 40, 3])

# %%
plt.figure(figsize=(16, 6))
length_ = 125
for i in range(recovered_sim_data.shape[1]):
    plt.subplot(1, 3, i+1)
    plt.plot(recovered_raw_data[:length_, i], label="Raw", linestyle='--')
    plt.plot(recovered_sim_data[:length_, i], label="Recon")
    plt.plot(recovered_raw_sim_data[:length_, i], label="Sim", linestyle='--')
    plt.title(f'Channel {i+1}')
    plt.legend()
plt.tight_layout()
plt.show()

# %%
import shutil

ReSaved = True

mode_name = 'EC_TFCritic_ACC_HOVER_M1F3.pth'
folder_name = mode_name.split('.')[0]
folder_path = os.path.join(os.getcwd(), folder_name)
path = os.path.join(os.getcwd(), folder_name, mode_name)

if not os.path.exists(folder_path):
    os.makedirs(folder_path, exist_ok=True)

torch.save(gen, path)
print(f'Model Re-Saved to {path}')
# Out:
# Model Re-Saved to d:\Tjh\Platform\PHM\model\compare\EC_TFCritic_ACC_HOVER_M1F3\EC_TFCritic_ACC_HOVER_M1F3.pth
